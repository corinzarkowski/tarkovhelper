# %%
import os
import requests
import re
import csv
import json
import time
import html
import string
import itertools
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from geojson import Feature, FeatureCollection, Point

# %%
URL = 'https://escapefromtarkov.fandom.com/wiki/Quests'
data = requests.get(URL, stream=True)
quests = []

if (data.status_code == 200):
    for line in data.iter_lines():
        match = re.findall('mw-selflink selflink">Quests<', str(line))
        if match:
            match2 = re.findall('<a href="/wiki/([^"]*)" title="([^"]*)">', str(line))
            if match2:
                quests = match2[1:-1]

# %%
quests
# Out:
# [('Debut', 'Debut'),
#  ('Checking', 'Checking'),
#  ('Shootout_Picnic', 'Shootout Picnic'),
#  ('Delivery_from_the_Past', 'Delivery from the Past'),
#  ('BP_Depot', 'BP Depot'),
#  ('Bad_Rep_Evidence', 'Bad Rep Evidence'),
#  ('Ice_Cream_Cones', 'Ice Cream Cones'),
#  ('Postman_Pat_-_Part_1', 'Postman Pat - Part 1'),
#  ('Shaking_up_the_Teller', 'Shaking up the Teller'),
#  ('The_Punisher_-_Part_1', 'The Punisher - Part 1'),
#  ('The_Punisher_-_Part_2', 'The Punisher - Part 2'),
#  ('The_Punisher_-_Part_3', 'The Punisher - Part 3'),
#  ('The_Punisher_-_Part_4', 'The Punisher - Part 4'),
#  ('The_Punisher_-_Part_5', 'The Punisher - Part 5'),
#  ('The_Punisher_-_Part_6', 'The Punisher - Part 6'),
#  ('Polikhim_Hobo', 'Polikhim Hobo'),
#  ('Big_Customer', 'Big Customer'),
#  ('No_Offence', 'No Offence'),
#  ('Grenadier', 'Grenadier'),
#  ('Perfect_Mediator', 'Perfect Mediator'),
#  ('Insomnia', 'Insomnia'),
#  ('Test_Drive_-_Part_1', 'Test Drive - Part 1'),
#  ('Regulated_Materials', 'Regulated Materials'),
#  ('The_Bunker_-_Part_1', 'The Bunker - Part 1'),
#  ('The_Bunker_-_Part_2', 'The Bunker - Part 2'),
#  ('Anesthesia', 'Anesthesia'),
#  ('Search_Mission', 'Search Mission'),
#  ('Documents', 'Documents'),
#  ('No_Place_for_Renegades', 'No Place for Renegades'),
#  ('Capturing_Outposts', 'Capturing Outposts'),
#  ('Intimidator', 'Intimidator'),
#  ('Escort', 'Escort'),
#  ('Easy_Job_-_Part_1', 'Easy Job - Part 1'),
#  ('Easy_Job_-_Part_2', 'Easy Job - Part 2'),
#  ('Our_Own_Land', 'Our Own Land'),
#  ('Therapist#Quests', 'Therapist'),
#  ('Shortage', 'Shortage'),
#  ('Sanitary_Standards_-_Part_1', 'Sanitary Standards - Part 1'),
#  ('Sanitary_Standards_-_Part_2', 'Sanitary Standards - Part 2'),
#  ('Operation_Aquarius_-_Part_1', 'Operation Aquarius - Part 1'),
#  ('Operation_Aquarius_-_Part_2', 'Operation Aquarius - Part 2'),
#  ('Painkiller', 'Painkiller'),
#  ('Pharmacist', 'Pharmacist'),
#  ('Supply_Plans', 'Supply Plans'),
#  ('General_Wares', 'General Wares'),
#  ('Car_Repair', 'Car Repair'),
#  ('Health_Care_Privacy_-_Part_1', 'Health Care Privacy - Part 1'),
#  ('Health_Care_Privacy_-_Part_2', 'Health Care Privacy - Part 2'),
#  ('Health_Care_Privacy_-_Part_3', 'Health Care Privacy - Part 3'),
#  ('Health_Care_Privacy_-_Part_4', 'Health Care Privacy - Part 4'),
#  ('Health_Care_Privacy_-_Part_5', 'Health Care Privacy - Part 5'),
#  ('Postman_Pat_-_Part_2', 'Postman Pat - Part 2'),
#  ('Out_of_Curiosity', 'Out of Curiosity'),
#  ('Trust_Regain', 'Trust Regain'),
#  ('Hippocratic_Oath', 'Hippocratic Oath'),
#  ('Athlete', 'Athlete'),
#  ('Decontamination_Service', 'Decontamination Service'),
#  ('Private_Clinic', 'Private Clinic'),
#  ('An_Apple_a_Day_Keeps_the_Doctor_Away',
#   'An Apple a Day Keeps the Doctor Away'),
#  ('Colleagues_-_Part_1', 'Colleagues - Part 1'),
#  ('Colleagues_-_Part_2', 'Colleagues - Part 2'),
#  ('Colleagues_-_Part_3', 'Colleagues - Part 3'),
#  ('Disease_History', 'Disease History'),
#  ('Crisis', 'Crisis'),
#  ('Seaside_Vacation', 'Seaside Vacation'),
#  ('Lost_Contact', 'Lost Contact'),
#  ('Skier#Quests', 'Skier'),
#  ('Supplier', 'Supplier'),
#  ('The_Extortionist', 'The Extortionist'),
#  ('Stirrup', 'Stirrup'),
#  ('What%E2%80%99s_on_the_Flash_Drive%3F',
#   'What\\xe2\\x80\\x99s on the Flash Drive?'),
#  ('Golden_Swag', 'Golden Swag'),
#  ('Chemical_-_Part_1', 'Chemical - Part 1'),
#  ('Chemical_-_Part_2', 'Chemical - Part 2'),
#  ('Chemical_-_Part_3', 'Chemical - Part 3'),
#  ('Chemical_-_Part_4', 'Chemical - Part 4'),
#  ('Loyalty_Buyout', 'Loyalty Buyout'),
#  ('Friend_from_the_West_-_Part_1', 'Friend from the West - Part 1'),
#  ('Friend_from_the_West_-_Part_2', 'Friend from the West - Part 2'),
#  ('Vitamins_-_Part_1', 'Vitamins - Part 1'),
#  ('Vitamins_-_Part_2', 'Vitamins - Part 2'),
#  ('Lend-Lease_-_Part_1', 'Lend-Lease - Part 1'),
#  ('Informed_Means_Armed', 'Informed Means Armed'),
#  ('Chumming', 'Chumming'),
#  ('Kind_of_Sabotage', 'Kind of Sabotage'),
#  ('Setup', 'Setup'),
#  ('Flint', 'Flint'),
#  ('Silent_Caliber', 'Silent Caliber'),
#  ('Bullshit', 'Bullshit'),
#  ('Rigged_Game', 'Rigged Game'),
#  ('Safe_Corridor', 'Safe Corridor'),
#  ('Night_Sweep', 'Night Sweep'),
#  ('Long_Road', 'Long Road'),
#  ('Missing_Cargo', 'Missing Cargo'),
#  ('Peacekeeper#Quests', 'Peacekeeper'),
#  ('Fishing_Gear', 'Fishing Gear'),
#  ('Tigr_Safari', 'Tigr Safari'),
#  ('Scrap_Metal', 'Scrap Metal'),
#  ('Eagle_Eye', 'Eagle Eye'),
#  ('Humanitarian_Supplies', 'Humanitarian Supplies'),
#  ('The_Cult_-_Part_1', 'The Cult - Part 1'),
#  ('The_Cult_-_Part_2', 'The Cult - Part 2'),
#  ('Spa_Tour_-_Part_1', 'Spa Tour - Part 1'),
#  ('Spa_Tour_-_Part_2', 'Spa Tour - Part 2'),
#  ('Spa_Tour_-_Part_3', 'Spa Tour - Part 3'),
#  ('Spa_Tour_-_Part_4', 'Spa Tour - Part 4'),
#  ('Spa_Tour_-_Part_5', 'Spa Tour - Part 5'),
#  ('Spa_Tour_-_Part_6', 'Spa Tour - Part 6'),
#  ('Spa_Tour_-_Part_7', 'Spa Tour - Part 7'),
#  ('Cargo_X_-_Part_1', 'Cargo X - Part 1'),
#  ('Cargo_X_-_Part_2', 'Cargo X - Part 2'),
#  ('Cargo_X_-_Part_3', 'Cargo X - Part 3'),
#  ('Wet_Job_-_Part_1', 'Wet Job - Part 1'),
#  ('Wet_Job_-_Part_2', 'Wet Job - Part 2'),
#  ('Wet_Job_-_Part_3', 'Wet Job - Part 3'),
#  ('Wet_Job_-_Part_4', 'Wet Job - Part 4'),
#  ('Wet_Job_-_Part_5', 'Wet Job - Part 5'),
#  ('Wet_Job_-_Part_6', 'Wet Job - Part 6'),
#  ('The_Guide', 'The Guide'),
#  ('Peacekeeping_Mission', 'Peacekeeping Mission'),
#  ('Lend-Lease_-_Part_2', 'Lend-Lease - Part 2'),
#  ('Mentor', 'Mentor'),
#  ('Samples', 'Samples'),
#  ('TerraGroup_Employee', 'TerraGroup Employee'),
#  ('Revision_-_Part_1', 'Revision - Part 1'),
#  ('Revision_-_Part_2', 'Revision - Part 2'),
#  ('The_Cleaner', 'The Cleaner'),
#  ('Classified_Technologies', 'Classified Technologies'),
#  ('Special_Equipment', 'Special Equipment'),
#  ('Cargo_X_-_Part_4', 'Cargo X - Part 4'),
#  ('Counteraction', 'Counteraction'),
#  ('Overpopulation', 'Overpopulation'),
#  ('Trophies', 'Trophies'),
#  ('Mechanic#Quests', 'Mechanic'),
#  ('Gunsmith_-_Part_1', 'Gunsmith - Part 1'),
#  ('Gunsmith_-_Part_2', 'Gunsmith - Part 2'),
#  ('Gunsmith_-_Part_3', 'Gunsmith - Part 3'),
#  ('Gunsmith_-_Part_4', 'Gunsmith - Part 4'),
#  ('Gunsmith_-_Part_5', 'Gunsmith - Part 5'),
#  ('Gunsmith_-_Part_6', 'Gunsmith - Part 6'),
#  ('Gunsmith_-_Part_7', 'Gunsmith - Part 7'),
#  ('Gunsmith_-_Part_8', 'Gunsmith - Part 8'),
#  ('Gunsmith_-_Part_9', 'Gunsmith - Part 9'),
#  ('Gunsmith_-_Part_10', 'Gunsmith - Part 10'),
#  ('Gunsmith_-_Part_11', 'Gunsmith - Part 11'),
#  ('Gunsmith_-_Part_12', 'Gunsmith - Part 12'),
#  ('Gunsmith_-_Part_13', 'Gunsmith - Part 13'),
#  ('Gunsmith_-_Part_14', 'Gunsmith - Part 14'),
#  ('Gunsmith_-_Part_15', 'Gunsmith - Part 15'),
#  ('Gunsmith_-_Part_16', 'Gunsmith - Part 16'),
#  ('Farming_-_Part_1', 'Farming - Part 1'),
#  ('Farming_-_Part_2', 'Farming - Part 2'),
#  ('Farming_-_Part_3', 'Farming - Part 3'),
#  ('Farming_-_Part_4', 'Farming - Part 4'),
#  ('Signal_-_Part_1', 'Signal - Part 1'),
#  ('Signal_-_Part_2', 'Signal - Part 2'),
#  ('Signal_-_Part_3', 'Signal - Part 3'),
#  ('Signal_-_Part_4', 'Signal - Part 4'),
#  ('Bad_Habit', 'Bad Habit'),
#  ('Scout', 'Scout'),
#  ('Insider', 'Insider'),
#  ('Import', 'Import'),
#  ('Fertilizers', 'Fertilizers'),
#  ('Psycho_Sniper', 'Psycho Sniper'),
#  ('A_Shooter_Born_in_Heaven', 'A Shooter Born in Heaven'),
#  ('Introduction', 'Introduction'),
#  ('Chemistry_Closet', 'Chemistry Closet'),
#  ('Surplus_Goods', 'Surplus Goods'),
#  ('Back_Door', 'Back Door'),
#  ('Calibration', 'Calibration'),
#  ('The_Courier', 'The Courier'),
#  ('Corporate_Secrets', 'Corporate Secrets'),
#  ('Energy_Crisis', 'Energy Crisis'),
#  ('Ragman#Quests', 'Ragman'),
#  ('Only_Business', 'Only Business'),
#  ('Make_ULTRA_Great_Again', 'Make ULTRA Great Again'),
#  ('Big_Sale', 'Big Sale'),
#  ('The_Blood_of_War_-_Part_1', 'The Blood of War - Part 1'),
#  ('The_Blood_of_War_-_Part_2', 'The Blood of War - Part 2'),
#  ('The_Blood_of_War_-_Part_3', 'The Blood of War - Part 3'),
#  ('Dressed_to_Kill', 'Dressed to Kill'),
#  ('Gratitude', 'Gratitude'),
#  ('Sales_Night', 'Sales Night'),
#  ('Hot_Delivery', 'Hot Delivery'),
#  ('Database_-_Part_1', 'Database - Part 1'),
#  ('Database_-_Part_2', 'Database - Part 2'),
#  ('Minibus', 'Minibus'),
#  ('Sew_it_Good_-_Part_1', 'Sew it Good - Part 1'),
#  ('Sew_it_Good_-_Part_2', 'Sew it Good - Part 2'),
#  ('Sew_it_Good_-_Part_3', 'Sew it Good - Part 3'),
#  ('Sew_it_Good_-_Part_4', 'Sew it Good - Part 4'),
#  ('Textile_-_Part_1', 'Textile - Part 1'),
#  ('Textile_-_Part_2', 'Textile - Part 2'),
#  ('The_Key_to_Success', 'The Key to Success'),
#  ('Living_High_is_Not_a_Crime_-_Part_1',
#   'Living High is Not a Crime - Part 1'),
#  ('Living_High_is_Not_a_Crime_-_Part_2',
#   'Living High is Not a Crime - Part 2'),
#  ('Charisma_Brings_Success', 'Charisma Brings Success'),
#  ('No_Fuss_Needed', 'No Fuss Needed'),
#  ('Supervisor', 'Supervisor'),
#  ('Scavenger', 'Scavenger'),
#  ('Inventory_Check', 'Inventory Check'),
#  ('A_Fuel_Matter', 'A Fuel Matter'),
#  ('Long_Line', 'Long Line'),
#  ('Booze', 'Booze'),
#  ('The_Stylish_One', 'The Stylish One'),
#  ('Communication_Difficulties', 'Communication Difficulties'),
#  ('Jaeger#Quests', 'Jaeger'),
#  ('Acquaintance', 'Acquaintance'),
#  ('The_Survivalist_Path_-_Unprotected_but_Dangerous',
#   'The Survivalist Path - Unprotected but Dangerous'),
#  ('The_Survivalist_Path_-_Thrifty', 'The Survivalist Path - Thrifty'),
#  ('The_Survivalist_Path_-_Zhivchik', 'The Survivalist Path - Zhivchik'),
#  ('The_Survivalist_Path_-_Wounded_Beast',
#   'The Survivalist Path - Wounded Beast'),
#  ('The_Survivalist_Path_-_Tough_Guy', 'The Survivalist Path - Tough Guy'),
#  ('The_Survivalist_Path_-_Cold_Blooded',
#   'The Survivalist Path - Cold Blooded'),
#  ('The_Survivalist_Path_-_Junkie', 'The Survivalist Path - Junkie'),
#  ('The_Survivalist_Path_-_Eagle-Owl', 'The Survivalist Path - Eagle-Owl'),
#  ('The_Survivalist_Path_-_Combat_Medic',
#   'The Survivalist Path - Combat Medic'),
#  ('The_Huntsman_Path_-_Secured_Perimeter',
#   'The Huntsman Path - Secured Perimeter'),
#  ('The_Huntsman_Path_-_Trophy', 'The Huntsman Path - Trophy'),
#  ('The_Huntsman_Path_-_Forest_Cleaning',
#   'The Huntsman Path - Forest Cleaning'),
#  ('The_Huntsman_Path_-_Controller', 'The Huntsman Path - Controller'),
#  ('The_Huntsman_Path_-_Sellout', 'The Huntsman Path - Sellout'),
#  ('The_Huntsman_Path_-_Woods_Keeper', 'The Huntsman Path - Woods Keeper'),
#  ('The_Huntsman_Path_-_Justice', 'The Huntsman Path - Justice'),
#  ('The_Huntsman_Path_-_Evil_Watchman', 'The Huntsman Path - Evil Watchman'),
#  ('The_Huntsman_Path_-_Eraser_-_Part_1',
#   'The Huntsman Path - Eraser - Part 1'),
#  ('The_Huntsman_Path_-_Eraser_-_Part_2',
#   'The Huntsman Path - Eraser - Part 2'),
#  ('The_Huntsman_Path_-_Sadist', 'The Huntsman Path - Sadist'),
#  ('Ambulance', 'Ambulance'),
#  ('Shady_Business', 'Shady Business'),
#  ('Nostalgia', 'Nostalgia'),
#  ('Fishing_Place', 'Fishing Place'),
#  ('Courtesy_Visit', 'Courtesy Visit'),
#  ('Hunting_Trip', 'Hunting Trip'),
#  ('Reserve_(quest)', 'Reserve (quest)'),
#  ('The_Tarkov_Shooter_-_Part_1', 'The Tarkov Shooter - Part 1'),
#  ('The_Tarkov_Shooter_-_Part_2', 'The Tarkov Shooter - Part 2'),
#  ('The_Tarkov_Shooter_-_Part_3', 'The Tarkov Shooter - Part 3'),
#  ('The_Tarkov_Shooter_-_Part_4', 'The Tarkov Shooter - Part 4'),
#  ('The_Tarkov_Shooter_-_Part_5', 'The Tarkov Shooter - Part 5'),
#  ('The_Tarkov_Shooter_-_Part_6', 'The Tarkov Shooter - Part 6'),
#  ('The_Tarkov_Shooter_-_Part_7', 'The Tarkov Shooter - Part 7'),
#  ('The_Tarkov_Shooter_-_Part_8', 'The Tarkov Shooter - Part 8'),
#  ('Pest_control', 'Pest control'),
#  ('Swift_One', 'Swift One'),
#  ('The_Huntsman_Path_-_Relentless', 'The Huntsman Path - Relentless'),
#  ('The_Huntsman_Path_-_Factory_Chief', 'The Huntsman Path - Factory Chief'),
#  ('Hunter', 'Hunter'),
#  ('The_Hermit', 'The Hermit'),
#  ('The_Huntsman_Path_-_Outcasts', 'The Huntsman Path - Outcasts'),
#  ('Fence#Quests', 'Fence'),
#  ('Collector', 'Collector'),
#  ('The_Choice', 'The Choice'),
#  ('Compensation_for_Damage_-_Wager', 'Compensation for Damage - Wager'),
#  ('Compensation_for_Damage_-_Collection',
#   'Compensation for Damage - Collection'),
#  ('Compensation_for_Damage_-_Barkeep', 'Compensation for Damage - Barkeep'),
#  ('Compensation_for_Damage_-_Wergild', 'Compensation for Damage - Wergild'),
#  ('Compensation_for_Damage_-_Trust', 'Compensation for Damage - Trust')]

# %%
questData = {}
for quest in quests:
    questData[quest[1]] = {
        'url': quest[0]
    }


for questTuple in quests:
    quest = questTuple[1]
    URL = 'https://escapefromtarkov.fandom.com/wiki/' + questTuple[0]
    data = requests.get(URL, stream=True)
    if (data.status_code == 200):
        questData[quest]['maps'] = []
        questData[quest]['objectives'] = []
        objectiveLine = False

        for line in data.iter_lines():
            matchCustoms = re.findall('on Customs', str(line))
            if matchCustoms:
                questData[quest]['maps'].append('customs')

            matchLab = re.findall('on Lab', str(line))
            if matchLab:
                questData[quest]['maps'].append('lab')

            matchInterchange = re.findall('on Interchange', str(line))
            if matchInterchange:
                questData[quest]['maps'].append('interchange')

            matchWoods = re.findall('on Woods', str(line))
            if matchWoods:
                questData[quest]['maps'].append('woods')

            matchReserve = re.findall('on Reserve', str(line))
            if matchReserve:
                questData[quest]['maps'].append('reserve')

            matchShoreline = re.findall('on Shoreline', str(line))
            if matchShoreline:
                questData[quest]['maps'].append('shoreline')

            matchLighthouse = re.findall('on Lighthouse', str(line))
            if matchLighthouse:
                questData[quest]['maps'].append('lighthouse')

            matchFactory = re.findall('on Factory', str(line))
            if matchFactory:
                questData[quest]['maps'].append('factory')


            matchObjectives = re.findall('id="Objectives"', str(line))
            if matchObjectives:
                objectiveLine = True

            if objectiveLine and not matchObjectives:
                matchEndObjectives = re.findall('<h2>', str(line))
                if not matchEndObjectives:
                    matchObjective = re.findall('(?:>)(?:\s*|([^><]+))(?:<)', str(line)[2:])
                    questData[quest]['objectives'].append(''.join(matchObjective))
                else:
                    objectiveLine = False

questData
# Out:
# {'Debut': {'url': 'Debut',
#   'maps': ['customs', 'customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 5 Scavs on Customs',
#    'Obtain and hand over 2 MP-133 12ga shotguns']},
#  'Checking': {'url': 'Checking',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Obtain the Bronze pocket watch on a chain on Customs',
#    '(Optional) Obtain the key to the fuel tanker truck',
#    'Hand over the pocket watch']},
#  'Shootout Picnic': {'url': 'Shootout_Picnic',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Eliminate 15 Scavs on Woods']},
#  'Delivery from the Past': {'url': 'Delivery_from_the_Past',
#   'maps': ['customs', 'factory'],
#   'objectives': ["Obtain the secure folder in the Tarcone Director\\'s office at the Customs terminal warehouse",
#    'Stash the package in the Factory break room (2nd floor near Gate 3)',
#    'Survive and extract from Factory']},
#  'BP Depot': {'url': 'BP_Depot',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Locate and mark the first fuel tank with an MS2000 Marker on Customs',
#    'Locate and mark the second fuel tank with an MS2000 Marker on Customs',
#    'Locate and mark the third fuel tank with an MS2000 Marker on Customs',
#    'Locate and mark the fourth fuel tank with an MS2000 Marker on Customs',
#    'Survive and extract from the location']},
#  'Bad Rep Evidence': {'url': 'Bad_Rep_Evidence',
#   'maps': ['customs',
#    'factory',
#    'customs',
#    'customs',
#    'factory',
#    'customs',
#    'customs'],
#   'objectives': ['Obtain Secure Folder 0031 in the bunkhouse on Customs',
#    '(Optional) Gain access to the locked room in the office hallway on the third floor on Factory',
#    '(Optional) Obtain the Portable bunkhouse key',
#    'Hand over the folder',
#    'Survive and extract from the location']},
#  'Ice Cream Cones': {'url': 'Ice_Cream_Cones',
#   'maps': ['woods', 'woods', 'customs'],
#   'objectives': ['Find 3 AK-74 5.45x39 6L31 60-round magazinesin raid',
#    "(Optional) Find the key to the bunker in the TerraGroup employee\\'s dorm room",
#    '(Optional) Locate the locked bunker on Woods',
#    'Hand over the 3 AK-74 5.45x39 6L31 60-round magazines']},
#  'Postman Pat - Part 1': {'url': 'Postman_Pat_-_Part_1',
#   'maps': ['factory', 'factory', 'factory'],
#   'objectives': ["Obtain the letter on the messenger\\'s body on Factory",
#    'Survive and extract from the location',
#    'Hand over the letter to Therapist']},
#  'Shaking up the Teller': {'url': 'Shaking_up_the_Teller',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Obtain the valuable item in dorm room 203 on Customs',
#    '(Optional) Gain access to dorm room 214',
#    'Hand over the valuable item']},
#  'The Punisher - Part 1': {'url': 'The_Punisher_-_Part_1',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Eliminate 15 Scavs while using an AKM series weapon on Shoreline']},
#  'The Punisher - Part 2': {'url': 'The_Punisher_-_Part_2',
#   'maps': ['shoreline', 'shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Eliminate 12 Scavs while using a suppressed weapon  on Shoreline',
#    'Find 7 Lower half-masksin raid',
#    'Hand over the 7 half-masks']},
#  'The Punisher - Part 3': {'url': 'The_Punisher_-_Part_3',
#   'maps': ['customs', 'customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 25 Scavs while using an AKS-74U on Customs']},
#  'The Punisher - Part 4': {'url': 'The_Punisher_-_Part_4',
#   'maps': ['woods', 'shoreline', 'woods', 'woods', 'shoreline'],
#   'objectives': ['Eliminate 10 Scavs while using a 12ga shotgun on Woods',
#    'Eliminate 10 PMC operatives while wearing a balaclava (any type) and Scav Vest on Shoreline',
#    'Find 5 Bars A-2607 95H18 knivesin raid',
#    'Hand over the 5 Bars A-2607 95H18 knives']},
#  'The Punisher - Part 5': {'url': 'The_Punisher_-_Part_5',
#   'maps': [],
#   'objectives': ['Find a AK-74N assault riflein raid',
#    'Hand over the AK-74N',
#    'Find a Colt M4A1 assault riflein raid',
#    'Hand over the M4A1',
#    'Find 2 Makarov PM pistolsin raid',
#    'Hand over the 2 pistols',
#    'Eliminate 10 PMC operatives while wearing a PACA body armor and 6B47 helmet']},
#  'The Punisher - Part 6': {'url': 'The_Punisher_-_Part_6',
#   'maps': [],
#   'objectives': ['',
#    '',
#    '',
#    'Despite the objective wording, the dogtags do not need to be found in raid!',
#    '',
#    'Eliminate 15 PMC operatives while using SVD rifle (excluding Factory location)',
#    'Find 7 BEAR PMC dogtagsin raid',
#    'Hand over the 7 BEARdogtags',
#    'Find 7 USEC PMC dogtagsin raid',
#    'Hand over the 7 USECdogtags']},
#  'Polikhim Hobo': {'url': 'Polikhim_Hobo',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 25 Scavs on Customs']},
#  'Big Customer': {'url': 'Big_Customer',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Locate the transport with the chemicals on Customs',
#    'Mark the vehicle with an MS2000 Marker',
#    'Survive and extract from the location']},
#  'No Offence': {'url': 'No_Offence',
#   'maps': [],
#   'objectives': ['Obtain 10 M67 grenades', 'Hand over the 10 grenades']},
#  'Grenadier': {'url': 'Grenadier',
#   'maps': [],
#   'objectives': ['Eliminate 12 PMC operatives with grenades']},
#  'Perfect Mediator': {'url': 'Perfect_Mediator',
#   'maps': [],
#   'objectives': ['Reach level 4 loyalty with Ragman',
#    'Reach level 4 loyalty with Skier',
#    'Reach level 4 loyalty with Mechanic',
#    'Reach level 4 loyalty with Peacekeeper',
#    'Reach level 4 loyalty with Prapor',
#    'Reach level 4 loyalty with Therapist']},
#  'Insomnia': {'url': 'Insomnia',
#   'maps': [],
#   'objectives': ['Eliminate 30 PMCs during nighttime (22 to 05)']},
#  'Test Drive - Part 1': {'url': 'Test_Drive_-_Part_1',
#   'maps': [],
#   'objectives': ['Eliminate 5 PMCs using an M1A with a Hybrid 46 silencer and a Trijicon REAP-IR thermal scope']},
#  'Regulated Materials': {'url': 'Regulated_Materials',
#   'maps': ['reserve', 'reserve'],
#   'objectives': ['Find 6-Sten-140-M military batteryin raid',
#    'Hand over the military battery to Prapor',
#    'Find 5 OFZ 30x160mm shellsin raid',
#    'Hand over the 5 OFZ shells']},
#  'The Bunker - Part 1': {'url': 'The_Bunker_-_Part_1',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Locate the underground bunker on Reserve',
#    'Locate the control room in the underground bunker on Reserve',
#    'Survive and extract from the location']},
#  'The Bunker - Part 2': {'url': 'The_Bunker_-_Part_2',
#   'maps': [],
#   'objectives': ['Locate the hermetic door leading to the hospital (White Bishop)',
#    'Locate one of two hermetic doors leading to the academy building (Black Bishop)',
#    'Locate one of two hermetic doors leading to barracks \\xe2\\x84\\x961 (Black Pawn)',
#    'Locate one of two hermetic doors leading to barracks \\xe2\\x84\\x962 (White Pawn)',
#    'Locate the hermetic door leading to the building of the air control center (King)',
#    'Survive and extract from the location']},
#  'Anesthesia': {'url': 'Anesthesia',
#   'maps': ['shoreline', 'shoreline'],
#   'objectives': ['Mark the first trading post with an MS2000 Marker on Shoreline',
#    'Mark the second trading post with an MS2000 Marker on Shoreline',
#    'Mark the third trading post with an MS2000 Marker on Shoreline',
#    'Survive and extract from the location']},
#  'Search Mission': {'url': 'Search_Mission',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ["Locate Prapor\\'s missing convoy on Woods",
#    'Locate the temporary USEC camp',
#    'Survive and extract from the location']},
#  'Documents': {'url': 'Documents',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Obtain Military documents #1 in the command bunker offices on Reserve',
#    'Obtain Military documents #2 in the command bunker offices on Reserve',
#    'Obtain Military documents #3 in the command bunker offices on Reserve',
#    'Hand over the first documents',
#    'Hand over the second documents',
#    'Hand over the third documents']},
#  'No Place for Renegades': {'url': 'No_Place_for_Renegades',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Eliminate 5 Raiders in the command bunker on Reserve']},
#  'Capturing Outposts': {'url': 'Capturing_Outposts',
#   'maps': ['customs',
#    'woods',
#    'shoreline',
#    'customs',
#    'customs',
#    'woods',
#    'shoreline',
#    'customs',
#    'woods',
#    'shoreline'],
#   'objectives': ['Eliminate 15 PMC operatives at the Scav base on Customs',
#    'Eliminate 15 PMC operatives at the Scav base on Woods',
#    'Eliminate 15 PMC operatives at the pier on Shoreline']},
#  'Intimidator': {'url': 'Intimidator',
#   'maps': [],
#   'objectives': ['Eliminate 40 Scavs with headshots']},
#  'Escort': {'url': 'Escort',
#   'maps': ['customs',
#    'interchange',
#    'woods',
#    'reserve',
#    'shoreline',
#    'customs',
#    'shoreline'],
#   'objectives': ['You must not die or leave the raid while the task is active (Status: KIA, Left the Action, MIA, Ran Through)',
#    'Eliminate 4 PMCs on daytime Factory',
#    'Eliminate 4 PMCs on Customs',
#    'Eliminate 4 PMCs on Shoreline',
#    'Eliminate 4 PMCs on Reserve',
#    'Eliminate 4 PMCs on Woods',
#    'Eliminate 4 PMCs on Interchange',
#    'Eliminate 4 PMCs on The Lab']},
#  'Easy Job - Part 1': {'url': 'Easy_Job_-_Part_1',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Locate the helicopter at the water treatment plant on Lighthouse',
#    'Mark the helicopter with an MS2000 Marker',
#    'Survive and extract from the location']},
#  'Easy Job - Part 2': {'url': 'Easy_Job_-_Part_2',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Secure the area around the helicopter at the water treatment plant on Lighthouse']},
#  'Our Own Land': {'url': 'Our_Own_Land',
#   'maps': [],
#   'objectives': ['Eliminate 20 USEC PMC operatives all over the Lighthouse territory',
#    'Hand over 20 found in raidUSECPMC dogtags']},
#  'Therapist': {'url': 'Therapist#Quests', 'maps': [], 'objectives': []},
#  'Shortage': {'url': 'Shortage',
#   'maps': [],
#   'objectives': ['Find 3 Salewa first aid kitin raid',
#    'Hand over the 3 first aid kits']},
#  'Sanitary Standards - Part 1': {'url': 'Sanitary_Standards_-_Part_1',
#   'maps': ['factory', 'factory', 'factory'],
#   'objectives': ['Find 1 Gas analyzerin raid',
#    '(Optional) Get access to the lockedpumping station on Factory',
#    'Hand over the 1 Gas analyzer']},
#  'Sanitary Standards - Part 2': {'url': 'Sanitary_Standards_-_Part_2',
#   'maps': [],
#   'objectives': ['Find 2 Gas analyzersin raid',
#    'Hand over the 2 Gas analyzers to Therapist']},
#  'Operation Aquarius - Part 1': {'url': 'Operation_Aquarius_-_Part_1',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Locate the water hidden inside of the dorms on Customs',
#    'Survive and extract from the location']},
#  'Operation Aquarius - Part 2': {'url': 'Operation_Aquarius_-_Part_2',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 15 Scavs on Customs']},
#  'Painkiller': {'url': 'Painkiller',
#   'maps': ['shoreline', 'customs'],
#   'objectives': ['Find 4 Morphine injectorsin raid',
#    'Hand over the 4 injectors to Therapist']},
#  'Pharmacist': {'url': 'Pharmacist',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Obtain the case containing the device on Customs',
#    "(Optional) Locate the paramedic\\'s car on Customs",
#    '(Optional) Get into two-story dorm room 114 on Customs',
#    'Hand over the case']},
#  'Supply Plans': {'url': 'Supply_Plans',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Obtain the Secure Folder 0052 in the sawmill cabin on Woods',
#    'Hand over the folder']},
#  'General Wares': {'url': 'General_Wares',
#   'maps': ['interchange'],
#   'objectives': ['Find 15 Cans of beef stew (Small)in raid',
#    'Hand over the 15 cans']},
#  'Car Repair': {'url': 'Car_Repair',
#   'maps': [],
#   'objectives': ['Find 4 Car batteriesin raid',
#    'Find 8 Spark plugsin raid',
#    'Hand over the 4 batteries',
#    'Hand over the 8 spark plugs']},
#  'Health Care Privacy - Part 1': {'url': 'Health_Care_Privacy_-_Part_1',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Locate and mark the first ambulance with an MS2000 Marker on Shoreline',
#    'Locate and mark the second ambulance with an MS2000 Marker on Shoreline',
#    'Locate and mark the third ambulance with an MS2000 Marker on Shoreline',
#    'Survive and extract from the location']},
#  'Health Care Privacy - Part 2': {'url': 'Health_Care_Privacy_-_Part_2',
#   'maps': ['shoreline'],
#   'objectives': ["Search the room in the Health Resort for any documents about TerraGroup\\'s research",
#    'Hand over the retrieved information',
#    'Survive and extract from the location']},
#  'Health Care Privacy - Part 3': {'url': 'Health_Care_Privacy_-_Part_3',
#   'maps': [],
#   'objectives': ['Locate the van that belonged to the head of the health resort Medical Services',
#    'Take a sample of the blood',
#    'Hand over the blood sample',
#    'Survive and extract from the location']},
#  'Health Care Privacy - Part 4': {'url': 'Health_Care_Privacy_-_Part_4',
#   'maps': [],
#   'objectives': ['Reach the required 4 Health skill level']},
#  'Health Care Privacy - Part 5': {'url': 'Health_Care_Privacy_-_Part_5',
#   'maps': ['factory', 'factory'],
#   'objectives': ['Locate the drop spot on night-time Factory',
#    'Obtain 3 packs of Gunpowder "Kite" and stash them in the designated spot']},
#  'Postman Pat - Part 2': {'url': 'Postman_Pat_-_Part_2',
#   'maps': [],
#   'objectives': ['Hand over the letter from the messenger to Therapist']},
#  'Out of Curiosity': {'url': 'Out_of_Curiosity',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Find the transport with the chemicals on Customs',
#    'Mark the vehicle with an MS2000 Marker',
#    'Survive and extract from Customs']},
#  'Trust Regain': {'url': 'Trust_Regain',
#   'maps': [],
#   'objectives': ['Obtain 1 Dorm room 303 key',
#    'Obtain 1 ZB-014 key',
#    'Obtain 1 Military checkpoint key',
#    'Obtain 1 Gas station storage room key',
#    'Hand over 1 Dorm room 303 key',
#    'Hand over 1 ZB-014 key',
#    'Hand over 1 Customs military checkpoint key',
#    'Hand over 1 Gas station storage room key']},
#  'Hippocratic Oath': {'url': 'Hippocratic_Oath',
#   'maps': [],
#   'objectives': ['Hand over 500 USD to Therapist']},
#  'Athlete': {'url': 'Athlete',
#   'maps': [],
#   'objectives': ['Reach the required 10 Health skill level']},
#  'Decontamination Service': {'url': 'Decontamination_Service',
#   'maps': ['interchange', 'interchange', 'interchange'],
#   'objectives': ['Eliminate 40 Scavs from less than 60 meters away while wearing specific gear on Interchange']},
#  'Private Clinic': {'url': 'Private_Clinic',
#   'maps': [],
#   'objectives': ['Find 1 Ophthalmoscopein raid',
#    'Find 1 LEDX Skin Transilluminatorin raid',
#    'Hand over the 1 Ophthalmoscope',
#    'Hand over the 1 LEDX Skin Transilluminator']},
#  'An Apple a Day Keeps the Doctor Away': {'url': 'An_Apple_a_Day_Keeps_the_Doctor_Away',
#   'maps': [],
#   'objectives': ['Hand over 400,000 RUB']},
#  'Colleagues - Part 1': {'url': 'Colleagues_-_Part_1',
#   'maps': [],
#   'objectives': ['Locate group that was sent to the Health resort',
#    'Locate the group that was sent to the pier',
#    'Locate the group that was sent to the cottages',
#    'Survive and leave the area']},
#  'Colleagues - Part 2': {'url': 'Colleagues_-_Part_2',
#   'maps': [],
#   'objectives': ["Obtain Sanitar\\'s Surgery kit marked with a blue symbol",
#    "Hand over Sanitar\\'s Surgery kit to Therapist",
#    "Obtain Sanitar\\'s ophthalmoscope",
#    "Hand over Sanitar\\'s ophthalmoscope to Therapist"]},
#  'Colleagues - Part 3': {'url': 'Colleagues_-_Part_3',
#   'maps': [],
#   'objectives': ['Do not kill Sanitar',
#    'Obtain TerraGroup Labs keycard (Blue)',
#    'Hand over the keycard',
#    'Obtain TerraGroup Labs keycard (Green)',
#    'Hand over the keycard',
#    'Find AHF1-M stimulant injectorin raid',
#    'Hand over the injector',
#    'Find 3-(b-TG) stimulant injectorin raid',
#    'Hand over the injector']},
#  'Disease History': {'url': 'Disease_History',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Obtain Medical record #1 on Reserve',
#    'Obtain Medical record #2 on Reserve',
#    'Hand over the first journal to Therapist',
#    'Hand over the second journal to Therapist']},
#  'Crisis': {'url': 'Crisis',
#   'maps': [],
#   'objectives': ['Find 5 Portable defibrillatorin raid',
#    'Find 5 Ophthalmoscopein raid',
#    'Find 5 LEDX Skin Transilluminatorin raid',
#    'Find 20 Pile of medsin raid']},
#  'Seaside Vacation': {'url': 'Seaside_Vacation',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ["Find the informant\\'s briefcase on Lighthouse",
#    'Hand over the found package']},
#  'Lost Contact': {'url': 'Lost_Contact',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Find the lost group in the chalet area on Lighthouse',
#    'Survive and extract from the location']},
#  'Skier': {'url': 'Skier#Quests', 'maps': [], 'objectives': []},
#  'Supplier': {'url': 'Supplier',
#   'maps': [],
#   'objectives': ['Hand over 1 found in raidModule-3M armor to Skier',
#    'Hand over 1 found in raidTOZ-106 shotgun to Skier']},
#  'The Extortionist': {'url': 'The_Extortionist',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Obtain the hidden valuable cargo on Customs',
#    '(Optional) Locate the messengers body',
#    '(Optional) Find the place where the messenger hid the cargo',
#    'Hand over the valuable cargo to Skier']},
#  'Stirrup': {'url': 'Stirrup',
#   'maps': [],
#   'objectives': ['Eliminate 3 PMCs while using pistols']},
#  'What\\xe2\\x80\\x99s on the Flash Drive?': {'url': 'What%E2%80%99s_on_the_Flash_Drive%3F',
#   'maps': [],
#   'objectives': ['Find 2 Secure flash drivesin raid',
#    'Hand over 2 Secure flash drives to Skier']},
#  'Golden Swag': {'url': 'Golden_Swag',
#   'maps': ['customs', 'customs'],
#   'objectives': ['Find the Golden Zibbo lighter',
#    'Stash the Golden Zibbo lighter in the bunkhouse in the trailer parking lot on Customs']},
#  'Chemical - Part 1': {'url': 'Chemical_-_Part_1',
#   'maps': ['customs', 'customs', 'customs', 'shoreline'],
#   'objectives': ["Obtain information about the Deputy Chief\\'s past life on Customs",
#    '(Optional) Find the sleeping place of the former Deputy Chief of Security on Customs',
#    'Hand over the information to Skier',
#    'Obtain items that can help the investigation',
#    'Hand over the items to Skier']},
#  'Chemical - Part 2': {'url': 'Chemical_-_Part_2',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Find any evidence on Customs that could help with the investigation',
#    'Hand over the evidence to Skier',
#    'Find any information on Customs that could help with the investigation',
#    'Hand over the info to Skier']},
#  'Chemical - Part 3': {'url': 'Chemical_-_Part_3',
#   'maps': [],
#   'objectives': ['Obtain the chemical-filled syringe hidden in Factory',
#    'Hand over the chemical-filled syringe to Skier']},
#  'Chemical - Part 4': {'url': 'Chemical_-_Part_4',
#   'maps': ['customs'],
#   'objectives': ['Find the transport with the chemicals',
#    'Mark the chemical transport vehicle with an MS2000 Marker',
#    'Survive and extract from Customs']},
#  'Loyalty Buyout': {'url': 'Loyalty_Buyout',
#   'maps': [],
#   'objectives': ['Hand over 1,000,000 RUB to Skier']},
#  'Friend from the West - Part 1': {'url': 'Friend_from_the_West_-_Part_1',
#   'maps': [],
#   'objectives': ['Eliminate 7 USEC PMCs',
#    'Obtain 7 USECPMC dogtags',
#    'Hand over 7 USECPMC dogtags']},
#  'Friend from the West - Part 2': {'url': 'Friend_from_the_West_-_Part_2',
#   'maps': [],
#   'objectives': ['Hand over 6,000 USD to Skier']},
#  'Vitamins - Part 1': {'url': 'Vitamins_-_Part_1',
#   'maps': [],
#   'objectives': ['Obtain the first Chemical container',
#    'Hand over the first Chemical container to Skier',
#    'Obtain the second Chemical container',
#    'Hand over the second Chemical container to Skier',
#    'Obtain the third Chemical container',
#    'Hand over the third Chemical container to Skier']},
#  'Vitamins - Part 2': {'url': 'Vitamins_-_Part_2',
#   'maps': [],
#   'objectives': ['Find 4 Respiratorsin raid',
#    'Hand over 4 Respirators to Skier',
#    'Find 3 Medical bloodsetsin raid',
#    'Hand over 3 Medical bloodsets to Skier']},
#  'Lend-Lease - Part 1': {'url': 'Lend-Lease_-_Part_1',
#   'maps': ['woods', 'shoreline', 'woods', 'woods', 'shoreline'],
#   'objectives': ['Obtain the first Motor Controller on Woods',
#    'Hand over the first controller to Skier',
#    'Obtain the second Motor Controller on Shoreline',
#    'Hand over the second Motor Controller|controller to Skier',
#    'Obtain the third Motor Controller on Shoreline',
#    'Hand over the third controller to Skier',
#    'Obtain the first Single-axis Fiber Optic Gyroscope on Woods',
#    'Hand over the first Single-axis Fiber Optic Gyroscope to Skier',
#    'Obtain the second Single-axis Fiber Optic Gyroscope on Shoreline',
#    'Hand over the second Single-axis Fiber Optic Gyroscope to Skier']},
#  'Informed Means Armed': {'url': 'Informed_Means_Armed',
#   'maps': ['customs',
#    'interchange',
#    'woods',
#    'woods',
#    'customs',
#    'interchange',
#    'woods'],
#   'objectives': ['Install a WI-FI camera to watch the sawmill dock on Woods',
#    'Install a WI-FI camera to watch the road to the port on Customs',
#    'Install a WI-FI camera to watch the Kiba Arms store entrance on Interchange']},
#  'Chumming': {'url': 'Chumming',
#   'maps': ['customs',
#    'interchange',
#    'woods',
#    'interchange',
#    'customs',
#    'interchange'],
#   'objectives': ['Stash 3 Gold chains under the mattress next to BTR-80A in Generic Store on Interchange',
#    'Stash 3 Gold chains in the microwave on the 3rd floor of the dorm on Customs',
#    'Stash 3 Gold chains in the middle wooden cabin of the sawmill on Woods',
#    'Eliminate 5 PMCs on Interchange in the time period of 22:00-10:00']},
#  'Kind of Sabotage': {'url': 'Kind_of_Sabotage',
#   'maps': ['woods'],
#   'objectives': ['Hand over Secure Folder 0052 to Skier']},
#  'Setup': {'url': 'Setup',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 15 PMCs on Customs while wearing specific gear']},
#  'Flint': {'url': 'Flint',
#   'maps': [],
#   'objectives': ['Reach the required Stress resistance skill level of 6']},
#  'Silent Caliber': {'url': 'Silent_Caliber',
#   'maps': [],
#   'objectives': ['Eliminate 20 Scavs with using a suppressed 12 gauge shotgun',
#    'Eliminate 10 PMCs while using a suppressed 12 gauge shotgun']},
#  'Bullshit': {'url': 'Bullshit',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Obtain the Flash drive with fake info on Customs',
#    'Stash 1 SV-98 sniper rifle in the trash opposite of stairs on the 3rd floor of the dorm',
#    'Stash 1 Roler Submariner gold wrist watch in the trash opposite of stairs on the 3rd floor of the dorm',
#    'Stash the Flash drive with fake info in the trash opposite of stairs on the 3rd floor of the dorm',
#    'Do not kill Scavs at Customs until the quest is completed']},
#  'Rigged Game': {'url': 'Rigged_Game',
#   'maps': [],
#   'objectives': ['Put an MS2000 Marker on the medical container at the Health Resort on Shoreline',
#    'Put an MS2000 Marker on the medical container by cottages on Shoreline',
#    'Put an MS2000 Marker on the medical container at the pier on Shoreline',
#    'Survive and extract from the location']},
#  'Safe Corridor': {'url': 'Safe_Corridor',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Eliminate 10 Scavs in the underground warehouse on Reserve']},
#  'Night Sweep': {'url': 'Night_Sweep',
#   'maps': [],
#   'objectives': ['Find 12 unusual knivesin raid',
#    'Hand over 12 knives to Skier']},
#  'Long Road': {'url': 'Long_Road',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Eliminate 15 Scavs along the main road on Lighthouse']},
#  'Missing Cargo': {'url': 'Missing_Cargo',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Locate the crashed helicopter on Lighthouse',
#    "Find the informant\\'s intelligence folder",
#    'Hand over the folder']},
#  'Peacekeeper': {'url': 'Peacekeeper#Quests', 'maps': [], 'objectives': []},
#  'Fishing Gear': {'url': 'Fishing_Gear',
#   'maps': ['shoreline', 'shoreline'],
#   'objectives': ['Find the boat hidden next to the breakwater on Shoreline',
#    'Stash 1 sniper rifle in the boat',
#    'Stash 1 multitool in the boat',
#    'Survive and extract from the location']},
#  'Tigr Safari': {'url': 'Tigr_Safari',
#   'maps': ['customs', 'customs', 'customs', 'customs'],
#   'objectives': ['Mark the first Tigr vehicle with an MS2000 Marker on Customs',
#    'Mark the second Tigr vehicle with an MS2000 Marker on Customs',
#    'Mark the third Tigr vehicle with an MS2000 Marker on Customs',
#    'Survive and extract from the location']},
#  'Scrap Metal': {'url': 'Scrap_Metal',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Mark the first T-90 tank with an MS2000 Marker on Shoreline',
#    'Mark the second T-90 tank with an MS2000 Marker on Shoreline',
#    'Mark the third T-90 tank with an MS2000 Marker on Shoreline',
#    'Survive and extract from the location']},
#  'Eagle Eye': {'url': 'Eagle_Eye',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Find the first UAV crash site on Shoreline',
#    'Obtain the SAS disk from the first crashed drone',
#    'Hand over the first SAS disk  to Peacekeeper',
#    'Find the second UAV crash site on Shoreline',
#    'Obtain the SAS disk from the second crashed drone',
#    'Hand over the second SAS disk  to Peacekeeper']},
#  'Humanitarian Supplies': {'url': 'Humanitarian_Supplies',
#   'maps': ['shoreline', 'shoreline'],
#   'objectives': ['Mark the first truck with an MS2000 Marker',
#    '(Optional) Find the first truck that was holding the lost UN cargo on Shoreline',
#    'Mark the second truck with an MS2000 Marker',
#    '(Optional) Find the second truck that was holding the lost UN cargo on Shoreline',
#    'Obtain 5 MRE ration packs',
#    'Hand over 5 MRE ration packs to Peacekeeper',
#    'Survive and extract from the location',
#    'Eliminate 10 Scavs on Shoreline while wearing a UN uniform (MF-UNTAR body armor and UN helmet)']},
#  'The Cult - Part 1': {'url': 'The_Cult_-_Part_1',
#   'maps': ['shoreline', 'shoreline'],
#   'objectives': ['Find the missing informant on Shoreline',
#    'Survive and extract from the location']},
#  'The Cult - Part 2': {'url': 'The_Cult_-_Part_2',
#   'maps': ['customs', 'woods', 'shoreline', 'woods', 'customs', 'woods'],
#   'objectives': ['Put the MS2000 Marker in the first ritual spot on Woods',
#    'Put the MS2000 Marker in the ritual spot on Customs',
#    'Put the MS2000 Marker in the second ritual spot on Woods',
#    'Put the MS2000 Marker in the ritual spot on Shoreline']},
#  'Spa Tour - Part 1': {'url': 'Spa_Tour_-_Part_1',
#   'maps': ['shoreline', 'shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Headshot 7 Scavs on Shoreline while using a 12 gauge shotgun']},
#  'Spa Tour - Part 2': {'url': 'Spa_Tour_-_Part_2',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Mark the helicopter on Shoreline with an MS2000 Marker',
#    'Mark the safe road on Shoreline with an MS2000 Marker',
#    'Survive and extract from the location']},
#  'Spa Tour - Part 3': {'url': 'Spa_Tour_-_Part_3',
#   'maps': ['shoreline'],
#   'objectives': ['Find 1 WD-40 (100ml)in raid',
#    'Hand over 1 WD-40 (100ml) to Peacekeeper',
#    'Find 2 Clin window cleanersin raid',
#    'Hand over 2 Clin window cleaners to Peacekeeper',
#    'Find 2 Corrugated hosesin raid',
#    'Hand over 2 Corrugated hoses to Peacekeeper',
#    'Find 2 Ox bleachesin raid',
#    'Hand over 2 Ox bleaches to Peacekeeper']},
#  'Spa Tour - Part 4': {'url': 'Spa_Tour_-_Part_4',
#   'maps': [],
#   'objectives': ['Find the generators in the east wing of the Health Resort',
#    'Find the generators in the west wing of the Health Resort',
#    'Survive and extract from the location']},
#  'Spa Tour - Part 5': {'url': 'Spa_Tour_-_Part_5',
#   'maps': ['shoreline'],
#   'objectives': ['Obtain the key to the closed premises of the Sanatorium',
#    'Hand over the key to Peacekeeper']},
#  'Spa Tour - Part 6': {'url': 'Spa_Tour_-_Part_6',
#   'maps': [],
#   'objectives': ['Hand over 8,000 USD to Peacekeeper']},
#  'Spa Tour - Part 7': {'url': 'Spa_Tour_-_Part_7',
#   'maps': [],
#   'objectives': ['Find 4 Morphine injectorsin raid',
#    'Hand over 4 Morphine injectors to Peacekeeper',
#    'Find 2 Alkaline cleaners for heat exchangersin raid',
#    'Hand over 2 Alkaline cleaners for heat exchangers to Peacekeeper',
#    'Find 2 Corrugated hosesin raid',
#    'Hand over 2 Corrugated hoses to Peacekeeper',
#    'Find 2 5L propane tanksin raid',
#    'Hand over 2 5L propane tanks to Peacekeeper']},
#  'Cargo X - Part 1': {'url': 'Cargo_X_-_Part_1',
#   'maps': [],
#   'objectives': ['Obtain the data in the computer room in the east wing of the Health Resort',
#    'Hand over the retrieved data to Peacekeeper']},
#  'Cargo X - Part 2': {'url': 'Cargo_X_-_Part_2',
#   'maps': ['customs', 'shoreline'],
#   'objectives': ['Find the room with reservoirs in the Health Resort',
#    'Obtain any information about the second part of the cargo shipment',
#    'Hand over the retrieved information to Peacekeeper']},
#  'Cargo X - Part 3': {'url': 'Cargo_X_-_Part_3',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Find the hidden TerraGroup cargo on Shoreline',
#    'Survive and extract from the location']},
#  'Wet Job - Part 1': {'url': 'Wet_Job_-_Part_1',
#   'maps': ['shoreline', 'shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Eliminate 10 Scavs on Shoreline using a suppressed M4A1 or ADAR']},
#  'Wet Job - Part 2': {'url': 'Wet_Job_-_Part_2',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ["Find the fishermen\\'s dwelling on Shoreline",
#    'Mark the fishing table with an MS2000 Marker',
#    'Survive and extract from the location']},
#  'Wet Job - Part 3': {'url': 'Wet_Job_-_Part_3',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ["Find Artyom\\'s car on Shoreline",
#    'Survive and extract from the location']},
#  'Wet Job - Part 4': {'url': 'Wet_Job_-_Part_4',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ["Obtain a list of the resort\\'s tenants on Shoreline",
#    'Hand over the list of tenants to Peacekeeper']},
#  'Wet Job - Part 5': {'url': 'Wet_Job_-_Part_5',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ["Obtain information on Artyom\\'s work on Shoreline",
#    'Hand over the information to Peacekeeper']},
#  'Wet Job - Part 6': {'url': 'Wet_Job_-_Part_6',
#   'maps': [],
#   'objectives': ['Reach the required Sniper Rifles skill level of 7']},
#  'The Guide': {'url': 'The_Guide',
#   'maps': [],
#   'objectives': ['Survive and extract from Woods with the "Survived" exit status',
#    'Survive and extract from Customs with the "Survived" exit status',
#    'Survive and extract from Interchange with the "Survived" exit status',
#    'Survive and extract from Shoreline with the "Survived" exit status',
#    'Survive and extract from Factory with the "Survived" exit status',
#    'Survive and extract from The Lab with the "Survived" exit status',
#    'Survive and extract from Reserve with the "Survived" exit status']},
#  'Peacekeeping Mission': {'url': 'Peacekeeping_Mission',
#   'maps': ['customs',
#    'interchange',
#    'woods',
#    'shoreline',
#    'customs',
#    'woods',
#    'customs',
#    'interchange',
#    'woods'],
#   'objectives': ['Eliminate 12 Scavs on Woods while wearing a UN uniform (UN helmet, MF-UNTAR body armor, M4A1 rifle)',
#    'Eliminate 12 Scavs on Customs while wearing a UN uniform (UN helmet, MF-UNTAR body armor, M4A1 rifle)',
#    'Eliminate 12 Scavs on Interchange while wearing a UN uniform (UN helmet, MF-UNTAR body armor, M4A1 rifle)',
#    'Eliminate 12 Scavs on Shoreline while wearing a UN uniform (UN helmet, MF-UNTAR body armor, M4A1 rifle)']},
#  'Lend-Lease - Part 2': {'url': 'Lend-Lease_-_Part_2',
#   'maps': [],
#   'objectives': ['Find 2 Virtex programmable processorsin raid',
#    'Find 1 Military COFDM Wireless Signal Transmitterin raid',
#    'Hand over 2 Virtex programmable processors to Peacekeeper',
#    'Hand over 1 Military COFDM Wireless Signal Transmitter to Peacekeeper']},
#  'Mentor': {'url': 'Mentor',
#   'maps': [],
#   'objectives': ['Hand over 50,000 EUR to Peacekeeper']},
#  'Samples': {'url': 'Samples',
#   'maps': [],
#   'objectives': ['Find 1 M.U.L.E. stimulant injectorin raid',
#    'Hand over 1 M.U.L.E. stimulant injector to Peacekeeper',
#    'Find 1 "Obdolbos" cocktail injectorin raid',
#    'Hand over 1 "Obdolbos" cocktail injector to Peacekeeper',
#    'Find 1 Meldonin stimulant injectorin raid',
#    'Hand over 1 Meldonin stimulant injector to Peacekeeper',
#    'Find 1 AHF1-M stimulant injectorin raid',
#    'Hand over 1 AHF1-M stimulant injector to Peacekeeper',
#    'Find 1 P22 stimulant injectorin raid',
#    'Hand over 1 P22 stimulant injector to Peacekeeper',
#    'Find 1 L1 (Norepinephrine) stimulant injectorin raid',
#    'Hand over 1 L1 (Norepinephrine) stimulant injector to Peacekeeper',
#    'Find 1 3-(b-TG) stimulant injectorin raid',
#    'Hand over 1 3-(b-TG) stimulant injector to Peacekeeper']},
#  'TerraGroup Employee': {'url': 'TerraGroup_Employee',
#   'maps': [],
#   'objectives': ["Find Sanitar\\'s workplace in the Lab",
#    "Obtain information about Sanitar\\'s work",
#    'Hand over the Flash drive marked with blue tape to Peacekeeper']},
#  'Revision - Part 1': {'url': 'Revision_-_Part_1',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Find and inspect the first BMP-2 on Reserve',
#    'Mark the first BMP-2',
#    'Find and inspect the second BMP-2 on Reserve',
#    'Mark the second BMP-2',
#    'Find and inspect the third BMP-2 on Reserve',
#    'Mark the third BMP-2',
#    'Find and inspect the fourth BMP-2 on Reserve',
#    'Mark the fourth BMP-2',
#    'Find and inspect the first LAV III on Reserve',
#    'Mark the first LAV III',
#    'Find and inspect the second LAV III on Reserve',
#    'Find and inspect the T-90 tank on Reserve']},
#  'Revision - Part 2': {'url': 'Revision_-_Part_2',
#   'maps': [],
#   'objectives': ['Locate and mark the first BRDM with an MS2000 Marker',
#    'Locate and mark the second BRDM with an MS2000 Marker',
#    'Locate and mark the first Stryker with an MS2000 Marker',
#    'Locate and mark the second Stryker with an MS2000 Marker']},
#  'The Cleaner': {'url': 'The_Cleaner',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Eliminate 50 Scav Raiders on Reserve']},
#  'Classified Technologies': {'url': 'Classified_Technologies',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Obtain the package with T-90M Commander control panel on Reserve',
#    'Hand over the package to Peacekeeper']},
#  'Special Equipment': {'url': 'Special_Equipment',
#   'maps': [],
#   'objectives': ['Find 5 VPX Flash Storage Modulesin raid',
#    'Find 5 UHF RFID Readersin raid',
#    'Find 5 Virtex programmable processorsin raid',
#    'Find 5 Military COFDM Wireless Signal Transmittersin raid',
#    'Handover 5 VPX Flash Storage Modules to Peacekeeper',
#    'Handover 5 UHF RFID Readers to Peacekeeper',
#    'Handover 5 Virtex programmable processors to Peacekeeper',
#    'Handover 5 Military COFDM Wireless Signal Transmitters to Peacekeeper']},
#  'Cargo X - Part 4': {'url': 'Cargo_X_-_Part_4',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Locate and mark the TerraGroup cargo with an MS2000 Marker on Lighthouse',
#    'Survive and extract from the location']},
#  'Counteraction': {'url': 'Counteraction',
#   'maps': [],
#   'objectives': ['Eliminate 20 BEAR PMC operatives all over the Lighthouse territory',
#    'Hand over 20 found in raidBEARPMC dogtags']},
#  'Overpopulation': {'url': 'Overpopulation',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Secure the cottage area from Scavs on Lighthouse']},
#  'Trophies': {'url': 'Trophies',
#   'maps': [],
#   'objectives': ['Find in raid 20 BEARPMC dogtags of level 50+',
#    'Find in raid 20 USECPMC dogtags of level 50+',
#    'Handover 20 BEARPMC dogtags of level 50+ to Peacekeeper',
#    'Handover 20 USECPMC dogtags of level 50+ to Peacekeeper']},
#  'Mechanic': {'url': 'Mechanic#Quests', 'maps': [], 'objectives': []},
#  'Gunsmith - Part 1': {'url': 'Gunsmith_-_Part_1',
#   'maps': [],
#   'objectives': ['Modify an MP-133 to comply with the required specification']},
#  'Gunsmith - Part 2': {'url': 'Gunsmith_-_Part_2',
#   'maps': [],
#   'objectives': ['Modify an AKS-74U to comply with the given specifications']},
#  'Gunsmith - Part 3': {'url': 'Gunsmith_-_Part_3',
#   'maps': [],
#   'objectives': ['Modify an MP5 to comply with the given specifications']},
#  'Gunsmith - Part 4': {'url': 'Gunsmith_-_Part_4',
#   'maps': [],
#   'objectives': ['Modify an M4A1 to comply with the given specifications']},
#  'Gunsmith - Part 5': {'url': 'Gunsmith_-_Part_5',
#   'maps': [],
#   'objectives': ['Modify a DVL-10 to comply with the given specifications']},
#  'Gunsmith - Part 6': {'url': 'Gunsmith_-_Part_6',
#   'maps': [],
#   'objectives': ['Modify an R11 RSASS to comply with the given specifications']},
#  'Gunsmith - Part 7': {'url': 'Gunsmith_-_Part_7',
#   'maps': [],
#   'objectives': ['Modify a Remington Model 870 to comply with the given specifications']},
#  'Gunsmith - Part 8': {'url': 'Gunsmith_-_Part_8',
#   'maps': [],
#   'objectives': ['Modify an AKM to comply with the given specifications']},
#  'Gunsmith - Part 9': {'url': 'Gunsmith_-_Part_9',
#   'maps': [],
#   'objectives': ['Modify an AKS-74N to comply with the given specifications']},
#  'Gunsmith - Part 10': {'url': 'Gunsmith_-_Part_10',
#   'maps': [],
#   'objectives': ['Modify an AK-105 to comply with the given specifications']},
#  'Gunsmith - Part 11': {'url': 'Gunsmith_-_Part_11',
#   'maps': [],
#   'objectives': ['Modify an AS VAL to comply with the given specifications']},
#  'Gunsmith - Part 12': {'url': 'Gunsmith_-_Part_12',
#   'maps': [],
#   'objectives': ['Modify an AK-102 to comply with the required specification']},
#  'Gunsmith - Part 13': {'url': 'Gunsmith_-_Part_13',
#   'maps': [],
#   'objectives': ['Modify a SIG MPX to comply with the required specification']},
#  'Gunsmith - Part 14': {'url': 'Gunsmith_-_Part_14',
#   'maps': [],
#   'objectives': ['Modify an AKMN to comply with the required specification']},
#  'Gunsmith - Part 15': {'url': 'Gunsmith_-_Part_15',
#   'maps': [],
#   'objectives': ['Modify an M1A to comply with the required specification']},
#  'Gunsmith - Part 16': {'url': 'Gunsmith_-_Part_16',
#   'maps': [],
#   'objectives': ['Modify an M4A1 to comply with the required specification']},
#  'Farming - Part 1': {'url': 'Farming_-_Part_1',
#   'maps': ['factory', 'factory', 'factory', 'factory'],
#   'objectives': ['Fix the first control board with a Toolset on Factory',
#    'Fix the second control board with a Toolset on Factory',
#    'Survive and extract from the location']},
#  'Farming - Part 2': {'url': 'Farming_-_Part_2',
#   'maps': [],
#   'objectives': ['Find 2 Power cordsin raid',
#    'Hand over 2 Power cords to Mechanic',
#    'Find 4 T-Shaped Plugsin raid',
#    'Hand over 4 T-Shaped Plugs to Mechanic',
#    'Find 2 Printed circuit boardsin raid',
#    'Hand over 2 Printed circuit boards to Mechanic']},
#  'Farming - Part 3': {'url': 'Farming_-_Part_3',
#   'maps': ['customs', 'customs', 'customs'],
#   'objectives': ['Find the warehouse of seized goods on Customs',
#    'Obtain the package of graphics cards',
#    'Hand over the package of graphics cards to Mechanic']},
#  'Farming - Part 4': {'url': 'Farming_-_Part_4',
#   'maps': [],
#   'objectives': ['Find 3 Graphics cardsin raid',
#    'Hand over 3 Graphics cards to Mechanic',
#    'Find 8 CPU fansin raid',
#    'Hand over 8 CPU fans to Mechanic']},
#  'Signal - Part 1': {'url': 'Signal_-_Part_1',
#   'maps': [],
#   'objectives': ['Find the first signal source',
#    'Find the second signal source',
#    'Survive and extract from the location']},
#  'Signal - Part 2': {'url': 'Signal_-_Part_2',
#   'maps': [],
#   'objectives': ['Find 3 PC CPUsin raid',
#    'Hand over 3 PC CPUs to Mechanic',
#    'Find 3 Rechargeable batteriesin raid',
#    'Hand over 3 Rechargeable batteries to Mechanic',
#    'Find 3 Printed circuit boardsin raid',
#    'Hand over 3 Printed circuit boards to Mechanic',
#    'Find 3 Broken GPhone smartphonesin raid',
#    'Hand over 3 Broken GPhone smartphones to Mechanic']},
#  'Signal - Part 3': {'url': 'Signal_-_Part_3',
#   'maps': ['shoreline', 'shoreline', 'shoreline'],
#   'objectives': ['Place the first Signal Jammer on the specified place on Shoreline',
#    'Place the second Signal Jammer on the specified place on Shoreline',
#    'Place the third Signal Jammer on the specified place on Shoreline',
#    'Survive and extract from the location']},
#  'Signal - Part 4': {'url': 'Signal_-_Part_4',
#   'maps': [],
#   'objectives': ['Reach the required Memory skill level of 4']},
#  'Bad Habit': {'url': 'Bad_Habit',
#   'maps': [],
#   'objectives': ['Find 5 Malboro cigarettesin raid',
#    'Hand over 5 Malboro cigarettes to Mechanic',
#    'Find 5 Strike cigarettesin raid',
#    'Hand over 5 Strike cigarettes to Mechanic',
#    'Find 5 Wilston cigarettesin raid',
#    'Hand over 5 Wilston cigarettes to Mechanic']},
#  'Scout': {'url': 'Scout',
#   'maps': [],
#   'objectives': ['Find the first Factory extraction',
#    'Find the second Factory extraction',
#    'Find the third Factory extraction',
#    'Survive and extract from the location']},
#  'Insider': {'url': 'Insider',
#   'maps': [],
#   'objectives': ['Reach level 3 loyalty with Prapor']},
#  'Import': {'url': 'Import',
#   'maps': [],
#   'objectives': ['Find 1 UHF RFID Fixed Readerin raid',
#    'Find 1 VPX Flash Storage Modulein raid',
#    'Hand over 1 UHF RFID Fixed Reader to Mechanic',
#    'Hand over 1 VPX Flash Storage Module to Mechanic']},
#  'Fertilizers': {'url': 'Fertilizers',
#   'maps': ['interchange'],
#   'objectives': ['Find 5 Bundle of wiresin raid',
#    'Find 5 Capacitorsin raid',
#    'Handover 5 Bundle of wires to Mechanic',
#    'Handover 5 Capacitors to Mechanic']},
#  'Psycho Sniper': {'url': 'Psycho_Sniper',
#   'maps': [],
#   'objectives': ['Reach the required Sniper Rifles skill level of 9']},
#  'A Shooter Born in Heaven': {'url': 'A_Shooter_Born_in_Heaven',
#   'maps': ['customs',
#    'woods',
#    'reserve',
#    'shoreline',
#    'woods',
#    'reserve',
#    'customs',
#    'woods',
#    'reserve',
#    'shoreline'],
#   'objectives': ['Headshot 3 PMCs on Woods from a distance of more than 100 meters',
#    'Headshot 3 PMCs on Reserve from a distance of more than 100 meters',
#    'Headshot 3 PMCs on Shoreline from a distance of more than 100 meters',
#    'Headshot 3 PMCs on Customs from a distance of more than 100 meters']},
#  'Introduction': {'url': 'Introduction',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ["Find Jaeger\\'s camp on Woods",
#    "Obtain Jaeger\\'s encrypted message",
#    'Hand over the message to Mechanic']},
#  'Chemistry Closet': {'url': 'Chemistry_Closet',
#   'maps': [],
#   'objectives': ["Find Sanitar's office in the health resort",
#    'Survive and extract from the location']},
#  'Surplus Goods': {'url': 'Surplus_Goods',
#   'maps': ['reserve', 'reserve', 'reserve', 'reserve'],
#   'objectives': ['Obtain MBT Integrated Navigation System on Reserve',
#    'Hand over the navigation complex to Mechanic']},
#  'Back Door': {'url': 'Back_Door',
#   'maps': ['reserve', 'reserve', 'reserve', 'reserve'],
#   'objectives': ['Find the unpowered secret exit on Reserve',
#    'Extract through that exit']},
#  'Calibration': {'url': 'Calibration',
#   'maps': [],
#   'objectives': ['Eliminate 20 PMCs from at least 100m away']},
#  'The Courier': {'url': 'The_Courier',
#   'maps': ['customs', 'customs', 'customs', 'customs'],
#   'objectives': ['Stash a Trijicon REAP-IR under the base of the yellow crane on the construction site on Customs',
#    'Stash a Trijicon REAP-IR behind the trash containers at the "new" gas station on Customs']},
#  'Corporate Secrets': {'url': 'Corporate_Secrets',
#   'maps': [],
#   'objectives': ['Find the data on water pump operation',
#    'Hand over the extracted data',
#    'Find the data on pumping station operation',
#    'Hand over the extracted data']},
#  'Energy Crisis': {'url': 'Energy_Crisis',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ['Find and mark the group of fuel tanks with an MS2000 Marker on Lighthouse',
#    'Find and mark the first tanker truck with an MS2000 Marker on Lighthouse',
#    'Find and mark the second tanker truck with an MS2000 Marker on Lighthouse',
#    'Find and mark the third tanker truck with an MS2000 Marker on Lighthouse']},
#  'Ragman': {'url': 'Ragman#Quests', 'maps': [], 'objectives': []},
#  'Only Business': {'url': 'Only_Business',
#   'maps': [],
#   'objectives': ['Obtain level 2 loyalty with Ragman']},
#  'Make ULTRA Great Again': {'url': 'Make_ULTRA_Great_Again',
#   'maps': ['interchange', 'interchange', 'interchange'],
#   'objectives': ['Eliminate 25 Scavs on Interchange']},
#  'Big Sale': {'url': 'Big_Sale',
#   'maps': [],
#   'objectives': ['Check the AVOKADO store',
#    'Check the KOSTIN store',
#    'Check the tRend store',
#    'Check the DINO CLOTHES store',
#    'Check the TOP BRAND store',
#    'Survive and extract from the location']},
#  'The Blood of War - Part 1': {'url': 'The_Blood_of_War_-_Part_1',
#   'maps': [],
#   'objectives': ['Mark the first tank',
#    'Mark the second tank',
#    'Mark the third tank',
#    'Survive and extract from the location']},
#  'The Blood of War - Part 2': {'url': 'The_Blood_of_War_-_Part_2',
#   'maps': ['reserve',
#    'interchange',
#    'interchange',
#    'interchange',
#    'shoreline'],
#   'objectives': ['Find 4 Fuel conditionersin raid',
#    'Hand over 4 Fuel conditioners to Ragman']},
#  'The Blood of War - Part 3': {'url': 'The_Blood_of_War_-_Part_3',
#   'maps': ['woods', 'woods', 'woods', 'woods'],
#   'objectives': ['Find and mark the first fuel stash with an MS2000 Marker on Woods',
#    'Find and mark the second fuel stash with an MS2000 Marker on Woods',
#    'Find and mark the third fuel stash with an MS2000 Marker on Woods',
#    'Survive and extract from the location']},
#  'Dressed to Kill': {'url': 'Dressed_to_Kill',
#   'maps': [],
#   'objectives': ['Find 2 Kinda Cowboy hatsin raid',
#    'Find 2 Ushanka ear-flap capsin raid',
#    'Hand over 2 Ushanka ear-flap caps to Ragman',
#    'Hand over 2 Kinda Cowboy hats to Ragman']},
#  'Gratitude': {'url': 'Gratitude',
#   'maps': ['woods'],
#   'objectives': ['Stash 1 Ghost balaclava in the specified place',
#    'Stash 1 Shemagh in the specified place',
#    'Stash 1 RayBench sunglasses in the specified place',
#    'Stash 1 Round frame sunglasses in the specified place']},
#  'Sales Night': {'url': 'Sales_Night',
#   'maps': ['interchange', 'interchange', 'interchange', 'interchange'],
#   'objectives': ['Survive and extract on Interchange 7 times']},
#  'Hot Delivery': {'url': 'Hot_Delivery',
#   'maps': ['interchange'],
#   'objectives': ['Stash 2 Peltor ComTac 2 in the specified place',
#    'Stash 2 6B47 Helmet in the specified place',
#    'Stash 2 BNTI "Gzhel-K" body armor in the specified place']},
#  'Database - Part 1': {'url': 'Database_-_Part_1',
#   'maps': ['interchange', 'interchange', 'interchange'],
#   'objectives': ['Obtain the Goshan cargo manifests on Interchange',
#    'Hand over the Goshan cargo manifests to Ragman',
#    'Obtain the OLI cargo manifests on Interchange',
#    'Hand over the OLI cargo manifests to Ragman',
#    'Obtain the IDEA cargo manifests on Interchange',
#    'Hand over the IDEA cargo manifests to Ragman']},
#  'Database - Part 2': {'url': 'Database_-_Part_2',
#   'maps': ['customs', 'interchange', 'interchange', 'interchange', 'customs'],
#   'objectives': ['Obtain the OLI cargo route documents on Interchange',
#    'Hand over the documents to Ragman']},
#  'Minibus': {'url': 'Minibus',
#   'maps': ['interchange', 'interchange', 'interchange'],
#   'objectives': ['Mark the first yellow minibus with an MS2000 Marker on Interchange',
#    'Mark the second yellow minibus with an MS2000 Marker on Interchange',
#    'Mark the third yellow minibus with an MS2000 Marker on Interchange',
#    'Survive and extract from the location']},
#  'Sew it Good - Part 1': {'url': 'Sew_it_Good_-_Part_1',
#   'maps': [],
#   'objectives': ['Find 1 Ski hat with holes for eyesin raid',
#    'Hand over 1 Ski hat with holes for eyes to Ragman',
#    'Find 1 Pilgrim tourist backpackin raid',
# ...
#   'objectives': ['Find 2 WARTECH TV-109 + TV-106 gear rigsin raid',
#    'Hand over 2 WARTECH TV-109 + TV-106 gear rigs to Ragman',
#    'Find 2 BlackRock chest rigsin raid',
#    'Hand over 2 BlackRock chest rigs to Ragman']},
#  'Textile - Part 1': {'url': 'Textile_-_Part_1',
#   'maps': ['interchange'],
#   'objectives': ['Find 5 Aramid fabricsin raid',
#    'Hand over 5 Aramid fabrics to Ragman',
#    'Find 10 Ripstop fabricsin raid',
#    'Hand over 10 Ripstop fabrics to Ragman',
#    'Find 3 Paracordsin raid',
#    'Hand over 3 Paracords to Ragman']},
#  'Textile - Part 2': {'url': 'Textile_-_Part_2',
#   'maps': ['interchange'],
#   'objectives': ['Find 10 Fleece fabricsin raid',
#    'Hand over 10 Fleece fabrics to Ragman',
#    'Find 10 Cordura polyamide fabricsin raid',
#    'Hand over 10 Cordura polyamide fabrics to Ragman',
#    'Find 5 KEKTAPE duct tapesin raid',
#    'Hand over 5 KEKTAPE duct tapes to Ragman']},
#  'The Key to Success': {'url': 'The_Key_to_Success',
#   'maps': ['interchange', 'interchange', 'interchange'],
#   'objectives': ['Obtain the Clothes design handbook - Part 1 on Interchange',
#    'Hand over the Clothes design handbook - Part 1 to Ragman',
#    'Obtain the Clothes design handbook - Part 2 on Interchange',
#    'Hand over the Clothes design handbook - Part 2 to Ragman']},
#  'Living High is Not a Crime - Part 1': {'url': 'Living_High_is_Not_a_Crime_-_Part_1',
#   'maps': [],
#   'objectives': ['Find 2 Bronze lionsin raid',
#    'Hand over Bronze lions to Ragman',
#    'Find 2 Horse figurinesin raid',
#    'Hand over 2 Horse figurines to Ragman',
#    'Find 1 Cat figurinein raid',
#    'Hand over 1 Cat figurine to Ragman',
#    'Find 1 Roler Submariner gold wrist watchin raid',
#    'Hand over 1 Roler Submariner gold wrist watch to Ragman']},
#  'Living High is Not a Crime - Part 2': {'url': 'Living_High_is_Not_a_Crime_-_Part_2',
#   'maps': [],
#   'objectives': ['Find 3 Antique teapotsin raid',
#    'Find 2 Antique vasesin raid',
#    'Hand over 3 Antique teapots to Ragman',
#    'Hand over 2 Antique vases to Ragman']},
#  'Charisma Brings Success': {'url': 'Charisma_Brings_Success',
#   'maps': [],
#   'objectives': ['Reach the required Charisma skill level of 10']},
#  'No Fuss Needed': {'url': 'No_Fuss_Needed',
#   'maps': [],
#   'objectives': ['Reach level 3 loyalty with Therapist']},
#  'Supervisor': {'url': 'Supervisor',
#   'maps': [],
#   'objectives': ['Obtain the Goshan cash register key',
#    'Hand over the Goshan cash register key to Ragman']},
#  'Scavenger': {'url': 'Scavenger',
#   'maps': [],
#   'objectives': ['Reach the required Search skill level of 9']},
#  'Inventory Check': {'url': 'Inventory_Check',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Check the first arsenal in the eastern barracks (Black Pawn) on Reserve',
#    'Check the second arsenal in the eastern barracks (Black Pawn) on Reserve',
#    'Check the first arsenal in the southern barracks (White Pawn) on Reserve',
#    'Check the second arsenal in the southern barracks (White Pawn) on Reserve',
#    'Check the duty room in the eastern barracks (Black Pawn) on Reserve',
#    'Survive and extract from the location']},
#  'A Fuel Matter': {'url': 'A_Fuel_Matter',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Mark the first group of fuel tanks with an MS2000 Marker on Reserve',
#    'Mark the second group of fuel tanks with an MS2000 Marker on Reserve',
#    'Survive and extract from the location']},
#  'Long Line': {'url': 'Long_Line',
#   'maps': ['interchange', 'interchange', 'interchange'],
#   'objectives': ['Eliminate 30 PMCs inside the ULTRA mall on Interchange']},
#  'Booze': {'url': 'Booze',
#   'maps': [],
#   'objectives': ['Find 10 Bottles of Tarkovskaya vodkain raid',
#    'Find 10 Bottles of Dan Jackiel whiskeyin raid',
#    'Find 3 Canister with purified waterin raid',
#    'Hand over 10 Bottles of Tarkovskaya vodka to Ragman',
#    'Hand over 10 Bottles of Dan Jackiel whiskey to Ragman',
#    'Hand over 3 Canister with purified water to Ragman']},
#  'The Stylish One': {'url': 'The_Stylish_One',
#   'maps': [],
#   'objectives': ['Eliminate Killa 100 times']},
#  'Communication Difficulties': {'url': 'Communication_Difficulties',
#   'maps': ['lighthouse'],
#   'objectives': ['Recon the area around the Lighthouse',
#    'Survive and extract from the location']},
#  'Jaeger': {'url': 'Jaeger#Quests', 'maps': [], 'objectives': []},
#  'Acquaintance': {'url': 'Acquaintance',
#   'maps': [],
#   'objectives': ['Find 3 Iskra ration packin raid',
#    'Find 2 Emelya rye croutonsin raid',
#    'Find 2 Can of beef stew (Large)in raid']},
#  'The Survivalist Path - Unprotected but Dangerous': {'url': 'The_Survivalist_Path_-_Unprotected_but_Dangerous',
#   'maps': ['woods', 'woods', 'woods', 'woods'],
#   'objectives': ['Eliminate 5 Scavs without wearing any body armor on Woods']},
#  'The Survivalist Path - Thrifty': {'url': 'The_Survivalist_Path_-_Thrifty',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Stash 1 Iskra ration pack in the ZB-016 bunker on Woods',
#    'Stash 1 Bottle of water in the ZB-016 bunker on Woods',
#    'Stash 1 Iskra ration pack in the ZB-014 bunker on Woods',
#    'Stash 1 Bottle of water in the ZB-014 bunker on Woods']},
#  'The Survivalist Path - Zhivchik': {'url': 'The_Survivalist_Path_-_Zhivchik',
#   'maps': [],
#   'objectives': ['Survive for 5 minutes while being completely dehydrated',
#    'Survive and extract from the location']},
#  'The Survivalist Path - Wounded Beast': {'url': 'The_Survivalist_Path_-_Wounded_Beast',
#   'maps': [],
#   'objectives': ['Eliminate 3 Scavs while suffering from pain effect']},
#  'The Survivalist Path - Tough Guy': {'url': 'The_Survivalist_Path_-_Tough_Guy',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Eliminate 3 Scavs on Woods in a single raid without using any medicine']},
#  'The Survivalist Path - Cold Blooded': {'url': 'The_Survivalist_Path_-_Cold_Blooded',
#   'maps': [],
#   'objectives': ['Eliminate 2 PMCs with headshots while suffering from tremor effect']},
#  'The Survivalist Path - Junkie': {'url': 'The_Survivalist_Path_-_Junkie',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Eliminate 15 Scavs on Woods while under any stimulant effect']},
#  'The Survivalist Path - Eagle-Owl': {'url': 'The_Survivalist_Path_-_Eagle-Owl',
#   'maps': [],
#   'objectives': ['Eliminate 6 Scavs in the time period of 21:00-04:00 without using any NVGs or Thermal sights']},
#  'The Survivalist Path - Combat Medic': {'url': 'The_Survivalist_Path_-_Combat_Medic',
#   'maps': [],
#   'objectives': ['Reach the required Vitality skill level of 5']},
#  'The Huntsman Path - Secured Perimeter': {'url': 'The_Huntsman_Path_-_Secured_Perimeter',
#   'maps': ['factory', 'factory', 'factory'],
#   'objectives': ['Eliminate 6 PM\\xd0\\xa1s on Factory in the office area (on any floor)']},
#  'The Huntsman Path - Trophy': {'url': 'The_Huntsman_Path_-_Trophy',
#   'maps': [],
#   'objectives': ['Eliminate Reshala',
#    "Find 1 Reshala\\'s Golden TTin raid",
#    "Hand over 1 Reshala\\'s Golden TT to Jaeger"]},
#  'The Huntsman Path - Forest Cleaning': {'url': 'The_Huntsman_Path_-_Forest_Cleaning',
#   'maps': [],
#   'objectives': ['Eliminate 30 Scavs all over the Tarkov territory']},
#  'The Huntsman Path - Controller': {'url': 'The_Huntsman_Path_-_Controller',
#   'maps': [],
#   'objectives': ['Eliminate 2 PMCs while they are suffering from the stun effect']},
#  'The Huntsman Path - Sellout': {'url': 'The_Huntsman_Path_-_Sellout',
#   'maps': [],
#   'objectives': ['Eliminate Killa',
#    "Find 1 Killa\\'s helmetin raid",
#    "Hand over 1 Killa\\'s helmet to Jaeger"]},
#  'The Huntsman Path - Woods Keeper': {'url': 'The_Huntsman_Path_-_Woods_Keeper',
#   'maps': [],
#   'objectives': ['Eliminate Shturman',
#    "Find 1 Shturman\\'s stash keyin raid",
#    "Hand over 1 Shturman\\'s stash key to Jaeger"]},
#  'The Huntsman Path - Justice': {'url': 'The_Huntsman_Path_-_Justice',
#   'maps': [],
#   'objectives': ["Eliminate 3 Scavs dressed in police uniform (Reshala\\'s bodyguards)"]},
#  'The Huntsman Path - Evil Watchman': {'url': 'The_Huntsman_Path_-_Evil_Watchman',
#   'maps': ['customs', 'customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 5 PMCs in the Dorms area on Customs']},
#  'The Huntsman Path - Eraser - Part 1': {'url': 'The_Huntsman_Path_-_Eraser_-_Part_1',
#   'maps': [],
#   'objectives': ['Eliminate Glukhar']},
#  'The Huntsman Path - Eraser - Part 2': {'url': 'The_Huntsman_Path_-_Eraser_-_Part_2',
#   'maps': [],
#   'objectives': ['Eliminate 6 raiders']},
#  'The Huntsman Path - Sadist': {'url': 'The_Huntsman_Path_-_Sadist',
#   'maps': [],
#   'objectives': ['Eliminate Sanitar']},
#  'Ambulance': {'url': 'Ambulance',
#   'maps': [],
#   'objectives': ['Find 1 Portable defibrillatorin raid',
#    'Find 2 CMS surgery kitsin raid',
#    'Hand over 1 Portable defibrillator to Jaeger',
#    'Hand over 2 CMS surgery kits to Jaeger']},
#  'Shady Business': {'url': 'Shady_Business',
#   'maps': ['customs', 'woods'],
#   'objectives': ['Find 3 Secure Flash drivesin raid',
#    'Hand over 3 Secure Flash drives to Jaeger']},
#  'Nostalgia': {'url': 'Nostalgia',
#   'maps': ['shoreline'],
#   'objectives': ["Find Jaeger's room with a view of a bay in the Health Resort",
#    "Obtain Jaeger\\'s Photo album",
#    'Hand over the Photo album to Jaeger']},
#  'Fishing Place': {'url': 'Fishing_Place',
#   'maps': [],
#   'objectives': ['Find 2 TerraGroup Labs access keycardsin raid',
#    'Hand over 2 TerraGroup Labs access keycards to Jaeger']},
#  'Courtesy Visit': {'url': 'Courtesy_Visit',
#   'maps': ['shoreline', 'shoreline'],
#   'objectives': ["Find the chairman\\'s house in the abandoned village on Shoreline",
#    "Find the fisherman\\'s house in the abandoned village on Shoreline",
#    "Find the priest\\'s house in the abandoned village on Shoreline"]},
#  'Hunting Trip': {'url': 'Hunting_Trip',
#   'maps': [],
#   'objectives': ['Eliminate Shturman while using a M700 Sniper rifle with the specified scope']},
#  'Reserve (quest)': {'url': 'Reserve_(quest)',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Find the food storage location on Reserve']},
#  'The Tarkov Shooter - Part 1': {'url': 'The_Tarkov_Shooter_-_Part_1',
#   'maps': [],
#   'objectives': ['Eliminate 5 Scavs while using a bolt-action rifle with iron sights from at least 40 meters away']},
#  'The Tarkov Shooter - Part 2': {'url': 'The_Tarkov_Shooter_-_Part_2',
#   'maps': [],
#   'objectives': ['Make 3 leg hits while using a bolt-action rifle from at least 40 meters away',
#    'Make 2 headshots while using a bolt-action rifle from at least 40 meters away']},
#  'The Tarkov Shooter - Part 3': {'url': 'The_Tarkov_Shooter_-_Part_3',
#   'maps': [],
#   'objectives': ['Eliminate 3 PMCs while using a bolt-action rifle at close range (less than 25 meters away)']},
#  'The Tarkov Shooter - Part 4': {'url': 'The_Tarkov_Shooter_-_Part_4',
#   'maps': [],
#   'objectives': ['Reach the required Sniper Rifles skill level of 3']},
#  'The Tarkov Shooter - Part 5': {'url': 'The_Tarkov_Shooter_-_Part_5',
#   'maps': ['customs', 'customs', 'customs', 'customs'],
#   'objectives': ['Eliminate 8 Scavs on Customs while using a bolt-action rifle in the time period of 21:00-5:00']},
#  'The Tarkov Shooter - Part 6': {'url': 'The_Tarkov_Shooter_-_Part_6',
#   'maps': [],
#   'objectives': ['Eliminate 5 Sniper Scavs while using a bolt-action rifle']},
#  'The Tarkov Shooter - Part 7': {'url': 'The_Tarkov_Shooter_-_Part_7',
#   'maps': [],
#   'objectives': ['Eliminate 5 PMCs while using a suppressed bolt-action rifle from at least 45 meters away']},
#  'The Tarkov Shooter - Part 8': {'url': 'The_Tarkov_Shooter_-_Part_8',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Eliminate 3 PMCs in a single raid on Woods while using a bolt-action rifle']},
#  'Pest control': {'url': 'Pest_control',
#   'maps': ['reserve', 'reserve', 'reserve'],
#   'objectives': ['Eliminate 10 Scavs in the barracks area on Reserve']},
#  'Swift One': {'url': 'Swift_One',
#   'maps': ['woods', 'woods', 'woods'],
#   'objectives': ['Eliminate 20 PMCs without using any armor or helmets on Woods']},
#  'The Huntsman Path - Relentless': {'url': 'The_Huntsman_Path_-_Relentless',
#   'maps': [],
#   'objectives': ['You must not die or leave the raid while the task is active (Status: KIA, Left the Action, MIA, Ran Through)',
#    'Eliminate Tagilla',
#    'Eliminate Killa',
#    'Eliminate Reshala',
#    'Eliminate Shturman',
#    'Eliminate Glukhar',
#    'Eliminate Sanitar']},
#  'The Huntsman Path - Factory Chief': {'url': 'The_Huntsman_Path_-_Factory_Chief',
#   'maps': [],
#   'objectives': ['Eliminate Tagilla',
#    'Find 1 BOSS capin raid',
#    'Hand over 1 BOSS cap to Jaeger']},
#  'Hunter': {'url': 'Hunter',
#   'maps': [],
#   'objectives': ['Eliminate Shturman 25 times']},
#  'The Hermit': {'url': 'The_Hermit',
#   'maps': ['lighthouse', 'lighthouse', 'lighthouse'],
#   'objectives': ["Locate the hideout of Jaeger\\'s friend on Lighthouse",
#    'Find and obtain the message for Jaeger',
#    'Hand over the message']},
#  'The Huntsman Path - Outcasts': {'url': 'The_Huntsman_Path_-_Outcasts',
#   'maps': ['lighthouse'],
#   'objectives': ['Eliminate 10 Rogue USEC operatives']},
#  'Fence': {'url': 'Fence#Quests', 'maps': [], 'objectives': []},
#  'Collector': {'url': 'Collector',
#   'maps': [],
#   'objectives': ['Reach level 62',
#    'Find Old firesteelin raid',
#    'Hand over the Old firesteel',
#    'Find Antique axein raid',
#    'Hand over the Antique axe',
#    'Find Battered antique bookin raid',
#    'Hand over the Battered antique book',
#    'Find FireKlean gun lubein raid',
#    'Hand over the FireKlean gun lube',
#    'Find Golden roosterin raid',
#    'Hand over the Golden rooster',
#    'Find Silver Badgein raid',
#    'Hand over the Silver Badge',
#    "Find Deadlyslob\\'s beard oilin raid",
#    "Hand over the Deadlyslob\\'s beard oil",
#    'Find Golden 1GPhone smartphonein raid',
#    'Hand over the Golden 1GPhone smartphone',
#    'Find Jar of DevilDog mayoin raid',
#    'Hand over the Jar of DevilDog mayo',
#    'Find Can of spratsin raid',
#    'Hand over the Can of sprats',
#    'Find Fake mustachein raid',
#    'Hand over the Fake mustache',
#    'Find Kotton beaniein raid',
#    'Hand over the Kotton beanie',
#    'Find Raven figurinein raid',
#    'Hand over the Raven figurine',
#    'Find Pestily plague maskin raid',
#    'Hand over the Pestily plague mask',
#    'Find Shroud half-maskin raid',
#    'Hand over the Shroud half-mask',
#    "Find Can of Dr. Lupo\\'s coffee beansin raid",
#    "Hand over the Can of Dr. Lupo\\'s coffee beans",
#    'Find 42 Signature Blend English Teain raid',
#    'Hand over the 42 Signature Blend English Tea',
#    'Find Veritas guitar pickin raid',
#    'Hand over the Veritas guitar pick',
#    'Find Evasion armbandin raid',
#    'Hand over the Evasion armband',
#    'Find Can of RatCola sodain raid',
#    'Hand over the Can of RatCola soda',
#    'Find Loot Lord plushiein raid',
#    'Hand over the Loot Lord plushie',
#    'Find WZ Walletin raid',
#    'Hand over the WZ Wallet',
#    "Find LVNDMARK\\'s rat poisonin raid",
#    "Hand over the LVNDMARK\\'s rat poison",
#    'Find Smoke balaclavain raid',
#    'Hand over the Smoke balaclava']},
#  'The Choice': {'url': 'The_Choice',
#   'maps': [],
#   'objectives': ['Handover Secure container Epsilon']},
#  'Compensation for Damage - Wager': {'url': 'Compensation_for_Damage_-_Wager',
#   'maps': [],
#   'objectives': ['Eliminate 7 PMC operatives while using any AK-series assault rifle']},
#  'Compensation for Damage - Collection': {'url': 'Compensation_for_Damage_-_Collection',
#   'maps': [],
#   'objectives': ['Hand over the 2 found in raidColt M4A1 assault rifles']},
#  'Compensation for Damage - Barkeep': {'url': 'Compensation_for_Damage_-_Barkeep',
#   'maps': [],
#   'objectives': ['Hand over the found in raidBottle of Dan Jackiel whiskey',
#    'Hand over the 3 found in raidCan of TarCola soda']},
#  'Compensation for Damage - Wergild': {'url': 'Compensation_for_Damage_-_Wergild',
#   'maps': [],
#   'objectives': ['Hand over 1,000,000 RUB']},
#  'Compensation for Damage - Trust': {'url': 'Compensation_for_Damage_-_Trust',
#   'maps': [],
#   'objectives': ['Hand over the 5 found in raidBEARPMC dogtags',
#    'Hand over the 5 found in raidUSECPMC dogtags']}}

# %%
with open('quest_data.json', 'w') as f:
    json.dump(questData, f)
